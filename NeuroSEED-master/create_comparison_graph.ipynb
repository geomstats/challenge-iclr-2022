# %%
import pickle
import matplotlib

# %%
name='strings_test'
model,avg_loss,e_size,dist_types=pickle.load(open('./datasets/'+name+'.pkl','rb'))
# Out:
# {'train': tensor([[ 0., 79., 76.,  ..., 73., 84., 70.],
#         [79.,  0., 73.,  ..., 66., 68., 68.],
#         [76., 73.,  0.,  ..., 68., 78., 73.],
#         ...,
#         [73., 66., 68.,  ...,  0., 75., 67.],
#         [84., 68., 78.,  ..., 75.,  0., 78.],
#         [70., 68., 73.,  ..., 67., 78.,  0.]]), 'val': tensor([[ 0., 66., 46., 67., 77., 48., 60., 68., 68., 75.],
#         [66.,  0., 67., 67., 79., 77., 85., 71., 76., 81.],
#         [46., 67.,  0., 68., 75., 59., 60., 73., 73., 77.],
#         [67., 67., 68.,  0., 69., 70., 75., 71., 71., 75.],
#         [77., 79., 75., 69.,  0., 85., 89., 75., 70., 77.],
#         [48., 77., 59., 70., 85.,  0., 47., 76., 74., 85.],
#         [60., 85., 60., 75., 89., 47.,  0., 88., 79., 88.],
#         [68., 71., 73., 71., 75., 76., 88.,  0., 70., 74.],
#         [68., 76., 73., 71., 70., 74., 79., 70.,  0., 75.],
# ...
